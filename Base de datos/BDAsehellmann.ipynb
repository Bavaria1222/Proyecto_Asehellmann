-- %% [markdown]
-- # [AsehellmannBD]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [AsehellmannBD]    Script Date: 1/10/2023 21:27:50 ******/
CREATE DATABASE [AsehellmannBD]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'AsehellmannBD', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.ASOHELLMANNBD\MSSQL\DATA\AsehellmannBD.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'AsehellmannBD_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.ASOHELLMANNBD\MSSQL\DATA\AsehellmannBD_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [AsehellmannBD] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [AsehellmannBD].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [AsehellmannBD] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [AsehellmannBD] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [AsehellmannBD] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [AsehellmannBD] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [AsehellmannBD] SET ARITHABORT OFF 
GO
ALTER DATABASE [AsehellmannBD] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [AsehellmannBD] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [AsehellmannBD] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [AsehellmannBD] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [AsehellmannBD] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [AsehellmannBD] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [AsehellmannBD] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [AsehellmannBD] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [AsehellmannBD] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [AsehellmannBD] SET  ENABLE_BROKER 
GO
ALTER DATABASE [AsehellmannBD] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [AsehellmannBD] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [AsehellmannBD] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [AsehellmannBD] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [AsehellmannBD] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [AsehellmannBD] SET READ_COMMITTED_SNAPSHOT ON 
GO
ALTER DATABASE [AsehellmannBD] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [AsehellmannBD] SET RECOVERY FULL 
GO
ALTER DATABASE [AsehellmannBD] SET  MULTI_USER 
GO
ALTER DATABASE [AsehellmannBD] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [AsehellmannBD] SET DB_CHAINING OFF 
GO
ALTER DATABASE [AsehellmannBD] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [AsehellmannBD] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [AsehellmannBD] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [AsehellmannBD] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'AsehellmannBD', N'ON'
GO
ALTER DATABASE [AsehellmannBD] SET QUERY_STORE = ON
GO
ALTER DATABASE [AsehellmannBD] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[__EFMigrationsHistory]

-- %%
USE [AsehellmannBD]
GO

-- %%
/****** Object:  Table [dbo].[__EFMigrationsHistory]    Script Date: 1/10/2023 21:27:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[__EFMigrationsHistory](
	[MigrationId] [nvarchar](150) NOT NULL,
	[ProductVersion] [nvarchar](32) NOT NULL,
 CONSTRAINT [PK___EFMigrationsHistory] PRIMARY KEY CLUSTERED 
(
	[MigrationId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
/****** Object:  Table [dbo].[Usuario]    Script Date: 1/10/2023 21:27:50 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario](
	[id] [int] IDENTITY(1,1) NOT NULL,
	[nombre] [nvarchar](max) NOT NULL,
	[apellidos] [nvarchar](max) NOT NULL,
	[correo] [nvarchar](max) NOT NULL,
	[password] [nvarchar](max) NOT NULL,
	[fechaCreacion] [datetime2](7) NOT NULL,
	[role] [nvarchar](max) NOT NULL,
 CONSTRAINT [PK_Usuario] PRIMARY KEY CLUSTERED 
(
	[id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [AsehellmannBD]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [AsehellmannBD] SET  READ_WRITE 
GO
